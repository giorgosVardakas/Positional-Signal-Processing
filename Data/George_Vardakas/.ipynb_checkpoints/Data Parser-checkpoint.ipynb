# %%
import pandas as pd
import numpy as np

# %%
accelerometer_data = pd.read_csv("./George_Vardakas_Accelerometer.csv")
gyroscope_data = pd.read_csv("./George_Vardakas_Gyroscope.csv")
heartrate_data = pd.read_csv("./George_Vardakas_HeartRate.csv")
activities = pd.read_csv("./activities.csv")

# %%
accelerometer_data["activityid"].value_counts()
# Out:
# 104    74400
# 102    68400
# 101    54000
# 107    40800
# 115    40200
# 103    28800
# 106    18000
# 105    10800
# Name: activityid, dtype: int64

# %%
activities
# Out:
#     ACTIVITY_ID                 NAME
# 0           101              jogging
# 1           102              walking
# 2           103             standing
# 3           104              sitting
# 4           105               stairs
# 5           106       brushing teeth
# 6           107               eating
# 7           108  eating with fingers
# 8           109    drinking from cup
# 9           110              writing
# 10          111       lifting weight
# 11          112      folding clothes
# 12          113          having bath
# 13          114       washing plates
# 14          115             lying on

# %%
chosen_activities = [101, 102, 103, 104, 105, 106, 107, 115]
def create_df_accel_gyro(accelerometer_data, gyroscope_data, chosen_activities):
    accelerometer_data = accelerometer_data.loc[accelerometer_data["activityid"].isin(chosen_activities)]
    gyroscope_data = gyroscope_data.loc[gyroscope_data["activityid"].isin(chosen_activities)]
    accelerometer_data.reset_index(inplace=True)
    gyroscope_data.reset_index(inplace=True)
    df_accel_gyro = pd.DataFrame(accelerometer_data[["time", "sensordatax", "sensordatay", "sensordataz"]])
    df_accel_gyro.rename(columns={"time":"TIMESTAMP","sensordatax": "ACCEL_X", "sensordatay" : "ACCEL_Y", "sensordataz" : "ACCEL_Z"}, inplace=True)
    df_accel_gyro["GYRO_X"] = gyroscope_data["sensordatax"]
    df_accel_gyro["GYRO_Y"] = gyroscope_data["sensordatay"]
    df_accel_gyro["GYRO_Z"] = gyroscope_data["sensordataz"]
    df_accel_gyro["ACTIVITY_ID"] = gyroscope_data["activityid"]
    return df_accel_gyro

# %%
df_accel_gyro = create_df_accel_gyro(accelerometer_data, gyroscope_data, chosen_activities)

# %%
#df_accel_gyro.to_csv("./accel_gyro.csv", index=False)

# %%
df_accel_gyro["TIMESTAMP"] = pd.to_datetime(df_accel_gyro["TIMESTAMP"])#, format=datetime_format)

# %%
#df_accel_gyro.loc[df_accel_gyro["TIMESTAMP"] > pd.Timestamp("2021-14-09")]
#df_accel_gyro["ACTIVITY_ID"].loc[df_accel_gyro["TIMESTAMP"] > pd.Timestamp("2021-01-14")].value_counts()

# %% [markdown]
# ## Seperate users

# %%
# Set the days of the users
# Ted's days
# pragmatikh last date 2021-01-12
ted_first_day = pd.Timestamp("2021-01-09")
ted_last_day = pd.Timestamp("2021-01-13")

# Gregory's days
# pragmatikh last date 2021-01-15
greg_first_day = pd.Timestamp("2021-01-13")
greg_last_day = pd.Timestamp("2021-01-16")

# Kostakis' days
# pragmatikh last date 2021-01-28
bro_first_day = pd.Timestamp("2021-01-19")
bro_last_day = pd.Timestamp("2021-01-29")

# Euhs' days
# pragmatikh last date 2021-02-08
euh_first_day = pd.Timestamp("2021-02-06")
euh_last_day = pd.Timestamp("2021-02-10")

# Create separate dataframes
is_ted_days = (df_accel_gyro["TIMESTAMP"] >= ted_first_day) & (df_accel_gyro["TIMESTAMP"] < ted_last_day)
df_accel_gyro_ted = df_accel_gyro.loc[is_ted_days]

is_greg_days = (df_accel_gyro["TIMESTAMP"] >= greg_first_day) & (df_accel_gyro["TIMESTAMP"] < greg_last_day)
df_accel_gyro_greg = df_accel_gyro.loc[is_greg_days]

is_bro_days = (df_accel_gyro["TIMESTAMP"] >= bro_first_day) & (df_accel_gyro["TIMESTAMP"] < bro_last_day)
df_accel_gyro_bro = df_accel_gyro.loc[is_bro_days]

is_euh_days = (df_accel_gyro["TIMESTAMP"] >= euh_first_day) #& (df_accel_gyro["TIMESTAMP"] < euh_last_day)
df_accel_gyro_euh = df_accel_gyro.loc[is_euh_days]

# Drop the data from my dataframe
df_accel_gyro.drop(df_accel_gyro_ted.index, inplace=True)
df_accel_gyro.drop(df_accel_gyro_greg.index, inplace=True)
df_accel_gyro.drop(df_accel_gyro_bro.index, inplace=True)
df_accel_gyro.drop(df_accel_gyro_euh.index, inplace=True)

# Reset the indexs at dataframes
df_accel_gyro.reset_index(inplace=True, drop=True)
df_accel_gyro_ted.reset_index(inplace=True, drop=True)
df_accel_gyro_greg.reset_index(inplace=True, drop=True)
df_accel_gyro_bro.reset_index(inplace=True, drop=True)
df_accel_gyro_euh.reset_index(inplace=True, drop=True)

# %%
df_accel_gyro
# Out:
#                      TIMESTAMP   ACCEL_X   ACCEL_Y    ACCEL_Z    GYRO_X  \
# 0      2020-12-22 14:34:27.313 -1.224671 -1.425790   9.939831 -0.071375
# 1      2020-12-22 14:34:27.413 -1.189954 -1.409030   9.937437 -0.042611
# 2      2020-12-22 14:34:27.513 -1.356357 -1.251008   9.604632 -0.068178
# 3      2020-12-22 14:34:27.613 -1.040312 -0.345972   9.513650 -0.050069
# 4      2020-12-22 14:34:27.713 -1.016369  0.737436   9.024021 -0.256736
# ...                        ...       ...       ...        ...       ...
# 116395 2021-03-07 16:27:34.281 -2.233858 -6.383136   9.694418  8.220896
# 116396 2021-03-07 16:27:34.381 -1.625712  0.611736  11.438647  2.172140
# 116397 2021-03-07 16:27:34.481 -1.426988  3.131711   7.817307  0.971550
# 116398 2021-03-07 16:27:34.581  0.022745  5.057905   8.141730 -0.002131
# 116399 2021-03-07 16:27:34.681  1.680780  3.814079   9.793780 -0.970485
#
#           GYRO_Y    GYRO_Z  ACTIVITY_ID
# 0       0.041546 -0.052199          102
# 1      -0.007457 -0.086288          102
#
#           GYRO_Y    GYRO_Z  ACTIVITY_ID
# 0       0.004261  0.013848          104
# 1       0.000000 -0.003196          104
# 2      -0.005326 -0.011718          104
# 3       0.007457 -0.022370          104
# 4       0.024502 -0.003196          104
# ...          ...       ...          ...
# 106195 -0.189622 -0.110790          105
# 106196  0.521995 -1.382755          105
# 106197  0.507081 -1.489285          105
# 106198  0.530518 -1.574509          105
# 106199  0.938526  0.337699          105
#
# [106200 rows x 8 columns]

# %%
#df_accel_gyro_bro[["ACCEL_X" ,"ACCEL_Y" ,"ACCEL_Z" ,"GYRO_X" ,"GYRO_Y" ,"GYRO_Z"]].plot(figsize=(15, 8))
df_accel_gyro_bro
# Out:
#                     TIMESTAMP   ACCEL_X   ACCEL_Y   ACCEL_Z    GYRO_X  \
# 0     2021-01-19 12:47:08.453 -1.039115 -3.010800  9.006063 -0.693508
# 1     2021-01-19 12:47:08.553 -1.013975 -3.263396  9.441822 -0.274846
# 2     2021-01-19 12:47:08.653 -0.908627 -2.972491  9.089864  0.060721
# 3     2021-01-19 12:47:08.753 -1.336005 -2.877917  9.633364  0.239692
# 4     2021-01-19 12:47:08.853 -1.142069 -2.935380  9.395133 -0.069243
# ...                       ...       ...       ...       ...       ...
# 34795 2021-01-27 22:59:23.371 -9.205986 -2.050695  2.369134  0.025567
# 34796 2021-01-27 22:59:23.471 -9.183240 -2.038725  2.359557  0.012783
# 34797 2021-01-27 22:59:23.571 -9.261054 -2.062667  2.359557 -0.021305
# 34798 2021-01-27 22:59:23.671 -9.233520 -1.977671  2.330826 -0.013848
# 34799 2021-01-27 22:59:23.771 -9.207183 -2.103370  2.382303 -0.013848
#
#          GYRO_Y    GYRO_Z  ACTIVITY_ID
# 0     -0.148076 -0.254605          104
# 1     -0.185361 -0.088419          104
# 2      0.038350  0.043676          104
# 3      0.235430  0.094810          104
# 4     -0.101203  0.021305          104
# ...         ...       ...          ...
# 34795  0.003196 -0.022370          103
# 34796  0.000000 -0.025567          103
# 34797 -0.006392 -0.010653          103
# 34798  0.000000 -0.010653          103
# 34799  0.000000 -0.010653          103
#
# [34800 rows x 8 columns]

# %%
df_accel_gyro_euh
# Out:
# Empty DataFrame
# Columns: [TIMESTAMP, ACCEL_X, ACCEL_Y, ACCEL_Z, GYRO_X, GYRO_Y, GYRO_Z, ACTIVITY_ID]
# Index: []

# %%
#df_accel_gyro.to_csv("./accel_gyro_Geo.csv", index=False)
#df_accel_gyro_ted.to_csv("./accel_gyro_Ted.csv", index=False)
#df_accel_gyro_greg.to_csv("./accel_gyro_Gregory.csv", index=False)
#df_accel_gyro_bro.to_csv("./accel_gyro_Bro.csv", index=False)
#df_accel_gyro_euh.to_csv("./accel_gyro_Euh.csv", index=False)
