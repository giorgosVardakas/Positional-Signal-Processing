# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Importing the Data

# %%
data_path = "./Data/WISDM_ar_latest/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt"

# %%
# Reading the first 3000 lines
df = pd.read_csv(data_path, sep=",", lineterminator=";", nrows=3000, header=None)

# %%
df.head()
# Out:
#     0        1               2         3          4         5
# 0  33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1  33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2  33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3  33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4  33  Jogging  49106332290000 -1.184970  12.108489  7.205164

# %%
df.describe()
# Out:
#             0             2            3            4            5
# count  3000.0  3.000000e+03  3000.000000  3000.000000  3000.000000
# mean     33.0  4.952345e+13    -0.429223     8.835978     1.682444
# std       0.0  2.232021e+11     3.160440     5.064496     3.463754
# min      33.0  4.910596e+13   -14.246883   -10.610250   -14.437569
# 25%      33.0  4.941118e+13    -1.947710     5.706926     0.040861
# 50%      33.0  4.959546e+13    -0.422231     8.676162     1.375655
# 75%      33.0  4.969650e+13     1.314364    12.149350     3.146300
# max      33.0  4.983264e+13    12.299174    19.572440    16.167353

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3000 non-null   int64
#  1   1       3000 non-null   object
#  2   2       3000 non-null   int64
#  3   3       3000 non-null   float64
#  4   4       3000 non-null   float64
#  5   5       3000 non-null   float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 140.8+ KB

# %%
# Renaming the columns
columns = {0:"user_id", 1:"activity", 2:"yimestamp", 3:"x-acceleration", 4:"y-acceleration", 5:"z-acceleration"}
df = df.rename(columns = columns)

# %%
df
# Out:
#       user_id    activity       yimestamp  x-acceleration    y-accel   z-accel
# 0          33     Jogging  49105962326000       -0.694638  12.680544  0.503953
# 1          33     Jogging  49106062271000        5.012288  11.264028  0.953424
# 2          33     Jogging  49106112167000        4.903325  10.882658 -0.081722
# 3          33     Jogging  49106222305000       -0.612916  18.496431  3.023717
# 4          33     Jogging  49106332290000       -1.184970  12.108489  7.205164
# ...       ...         ...             ...             ...        ...       ...
# 2995       33  Downstairs  49832212326000        0.531194   5.434519  2.301839
# 2996       33  Downstairs  49832322311000       -1.184970   3.064578  2.342700
# 2997       33  Downstairs  49832432297000       -1.566340   7.586534  1.539099
# 2998       33  Downstairs  49832532272000       -2.533385  10.991621  2.260978
# 2999       33  Downstairs  49832642319000        1.838747  13.797412  2.451662
#
# [3000 rows x 6 columns]
